# %%
from fastbook import *
from fastai.vision.widgets import *

# %%
from fastai.vision.all import *

# %%
dls = ImageDataLoaders.from_folder(path='/home/',
                                   seed=42,
                                   item_tfms=RandomResizedCrop(224, min_scale=0.5),
                                   batch_tfms=aug_transforms())

# %%
dls.valid.show_batch(max_n=8, nrows=2)

# %%
dls.train.show_batch(max_n=8, nrows=2)

# %%
learn = cnn_learner(dls, resnet34, metrics=error_rate)
learn.fine_tune(4)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /home/.cache/torch/hub/checkpoints/resnet34-333f7ec4.pth
#   0%|          | 0.00/83.3M [00:00<?, ?B/s]
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>4.860176</td>
#       <td>2.180093</td>
#       <td>0.475025</td>
#       <td>00:15</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.930669</td>
#       <td>0.870638</td>
#       <td>0.203874</td>
#       <td>00:18</td>
#     </tr>
# ...

# %%
learn.export()

# %%
path = Path('/home/')
path.ls(file_exts='.pkl')
# Out:
# (#1) [Path('/home/export.pkl')]

# %%
pred,pred_idx,probs = learn.predict('/home/test/Pikachu/00000046.jpg')

# %%
img = PILImage.create('/home/test/Pikachu/00000046.jpg')

# %%
img.show()
# Out:
# <AxesSubplot:>

# %%
pred
# Out:
# 'Pikachu'

# %%
#interp = ClassificationInterpretation.from_learner(learn)
#interp.plot_confusion_matrix()

# %%
pred,pred_idx,probs = learn.predict('/home/test/Squirtle/00000050.png')
img = PILImage.create('/home/test/Squirtle/00000050.png')

# %%
img.show()
# Out:
# <AxesSubplot:>

# %%
pred
# Out:
# 'Squirtle'

# %%
pred,pred_idx,probs = learn.predict('/home/test/Jigglypuff/34d67f10c8114b8486318d190f770cfd.jpg')
img = PILImage.create('/home/test/Jigglypuff/34d67f10c8114b8486318d190f770cfd.jpg')

# %%
img.show()
# Out:
# <AxesSubplot:>

# %%
pred
# Out:
# 'Jigglypuff'

# %%
pred,pred_idx,probs = learn.predict('/home/test/Psyduck/4af560cb1a0046e8bfe871e7bf576750.jpg')
img = PILImage.create('/home/test/Psyduck/4af560cb1a0046e8bfe871e7bf576750.jpg')

# %%
img.show()
# Out:
# <AxesSubplot:>

# %%
pred
# Out:
# 'Psyduck'
