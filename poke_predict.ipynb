# %%
from fastbook import *
from fastai.vision.widgets import *
from fastai.vision.all import *

# %%
learn_inf = load_learner('/home/export.pkl')

# %%
pred,pred_idx,probs = learn_inf.predict('/home/test/Poliwhirl/5da743b762c941faa1ece41cea02cbca.jpg')

# %%
img = PILImage.create('/home/test/Poliwhirl/5da743b762c941faa1ece41cea02cbca.jpg')

# %%
img.show()
# Out:
# <AxesSubplot:>

# %%
pred
# Out:
# 'Poliwhirl'

# %%
pred,pred_idx,probs = learn_inf.predict('/home/test/Slowpoke/1f2d5ebede474547af32b27efff2b7dc.jpg')

# %%
img = PILImage.create('/home/test/Slowpoke/1f2d5ebede474547af32b27efff2b7dc.jpg')

# %%
img.show()
# Out:
# <AxesSubplot:>

# %%
pred
# Out:
# 'Slowpoke'
